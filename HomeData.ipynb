# %% [markdown]
# <a href="https://colab.research.google.com/github/nastynoice/Kaggle-Projects/blob/main/HomeData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor

# %%
#A decision tree is used for classification and prediction. 
#It has a flowchart like structure.

# %%
file_path = '/content/train (2).csv'
home_data = pd.read_csv(file_path)
home_data
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...        WD         Normal    208500
# 1        2          20       RL  ...        WD         Normal    181500
# 2        3          60       RL  ...        WD         Normal    223500
# 3        4          70       RL  ...        WD        Abnorml    140000
# 4        5          60       RL  ...        WD         Normal    250000
# ...    ...         ...      ...  ...       ...            ...       ...
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# 1457  1458          70       RL  ...        WD         Normal    266500
# 1458  1459          20       RL  ...        WD         Normal    142125
# 1459  1460          20       RL  ...        WD         Normal    147500
#
# [1460 rows x 81 columns]

# %%
#target object
y = home_data.SalePrice
#setting x
parameters = ['LotArea', 'YearBuilt', '1stFlrSF', '2ndFlrSF','BedroomAbvGr','TotRmsAbvGrd']
x = home_data[parameters]

# %%
#splitting data
train_x, test_x, train_y, test_y = train_test_split(x, y, random_state = 1)
#specifying model
model = DecisionTreeRegressor(random_state = 1)
#fit model
model.fit(train_x, train_y)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=1, splitter='best')

# %%
#predictions
predict = model.predict(test_x)
#MAE
mae = mean_absolute_error(predict, test_y)
mae
# Out:
# 28629.153424657536

# %%
##This code cell is to know the best leaf size that are model can have,
def get_mae(max_leaf_nodes, train_x, test_x, train_y, test_y):
  model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state = 1)
  model.fit(train_x, train_y)
  pred = model.predict(test_x)
  mae = mean_absolute_error(test_y, pred)
  return(mae)

# %%
##we select the one with least MAE
candidate_max_leaf_nodes = [5, 25, 50, 100, 250, 500]

score = {leaf_size: get_mae(leaf_size, train_x, test_x, train_y, test_y) for leaf_size in candidate_max_leaf_nodes}
best_size = min(score, key=score.get)
print(score)
best_size
# Out:
# {5: 35044.51299744237, 25: 29016.41319191076, 50: 27405.930473214907, 100: 27138.672422419033, 250: 27185.075356817113, 500: 28301.098309453104}
# 100

# %%
final = DecisionTreeRegressor(max_leaf_nodes=best_size, random_state = 1)
final.fit(x,y)
final.fit
# Out:
# <bound method DecisionTreeRegressor.fit of DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=100,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=1, splitter='best')>

# %%
#We use multiple trees instead of one and predict based on the average of
#the predictions of each subsequent tree

# %%
#Random Forests
#home_data = home_data.dropna(axis = 1) #dropping columns with NULL values
home_data
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...        WD         Normal    208500
# 1        2          20       RL  ...        WD         Normal    181500
# 2        3          60       RL  ...        WD         Normal    223500
# 3        4          70       RL  ...        WD        Abnorml    140000
# 4        5          60       RL  ...        WD         Normal    250000
# ...    ...         ...      ...  ...       ...            ...       ...
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# 1457  1458          70       RL  ...        WD         Normal    266500
# 1458  1459          20       RL  ...        WD         Normal    142125
# 1459  1460          20       RL  ...        WD         Normal    147500
#
# [1460 rows x 81 columns]

# %%
from sklearn.ensemble import RandomForestRegressor
RFmodel = RandomForestRegressor(random_state = 1)
RFmodel.fit(train_x, train_y)
RFpred = RFmodel.predict(test_x)
T = print(mean_absolute_error(test_y, RFpred))
# Out:
# 22278.05694977169

# %%
#Conclusion
#We observe that a Random Forest model is more accurate because
#The MAE in Random Forest is less than in Decision Tree by 6351.096 points

#Why we faced such a problem in Decision Tree?
#Well! Using only one tree causes the problem of Overfitting and Uderfitting,
#each arises in the cases of a Deep and Shallow Tree respectively

#Deep Tree overfits because each  prediction comes from historical data 
#only the few houses at its leaf

#Shallow Tree underfits because it fails to capture distinctions that
#are necessary to predict our target variable.
